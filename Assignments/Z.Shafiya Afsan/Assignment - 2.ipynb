# %% [markdown]
# ## Loading the Dataset

# %%
import pandas as pd

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %% [markdown]
# ## Visualizations

# %% [markdown]
# ## Univariate Analysis

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
import seaborn as sns

# %% [markdown]
# # Line Plot

# %%
df1=df.head(100)

# %%
df1
# Out:
#     RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602    Hargrave          619    France  Female   42
# 1           2    15647311        Hill          608     Spain  Female   41
# 2           3    15619304        Onio          502    France  Female   42
# 3           4    15701354        Boni          699    France  Female   39
# 4           5    15737888    Mitchell          850     Spain  Female   43
# ..        ...         ...         ...          ...       ...     ...  ...
# 95         96    15699461  Fiorentini          515     Spain    Male   35
# 96         97    15738721      Graham          773     Spain    Male   41
# 97         98    15693683      Yuille          814   Germany    Male   29
# 98         99    15604348      Allard          710     Spain    Male   22
# 99        100    15633059     Fanucci          413    France    Male   34
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0        2       0.00              1          1               1
# 1        1   83807.86              1          0               1
# 2        8  159660.80              3          1               0
# 3        1       0.00              2          0               0
# 4        2  125510.82              1          1               1
# ..     ...        ...            ...        ...             ...
# 95      10  176273.95              1          0               1
# 96       9  102827.44              1          0               1
# 97       8   97086.40              2          1               1
# 98       8       0.00              2          0               0
# 99       9       0.00              2          0               0
#
#     EstimatedSalary  Exited
# 0         101348.88       1
# 1         112542.58       0
# 2         113931.57       1
# 3          93826.63       0
# 4          79084.10       0
# ..              ...     ...
# 95        121277.78       0
# 96         64595.25       0
# 97        197276.13       0
# 98         99645.04       0
# 99          6534.18       0
#
# [100 rows x 14 columns]

# %%
df1.Age.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Dist Plot

# %%
sns.distplot(df.Age)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# ## Pie Chart

# %%
data = [2,3,5,10]
plt.pie(data,[0.1,0,0,0], labels=['t1','t2','t3','t4'], autopct='%0.2f')
plt.show()

# %% [markdown]
# ## Histogram

# %%
z = [1,1,2,4,5,3,5,6,7,9,8,7,5,6,6,6,4,3,3,8,9]
plt.hist(z)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ## Bar Graph

# %%
sns.barplot(df1.Age,df1.CreditScore)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='CreditScore'>

# %% [markdown]
# ## Scatter Plot

# %%
sns.scatterplot(df1.Age,df1.CreditScore)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='CreditScore'>

# %% [markdown]
# ## Box Plot

# %%
sns.boxplot(df1.Age,df1.CreditScore)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='CreditScore'>

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ## Pair Plot

# %%
df2=df.head(20)

# %%
sns.pairplot(df2)

# %% [markdown]
# ## Descriptive Statics

# %%
import numpy as np

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9233 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        9233 non-null   int64
#  1   CustomerId       9233 non-null   int64
#  2   Surname          9233 non-null   int32
#  3   CreditScore      9233 non-null   int64
#  4   Geography        9233 non-null   int32
#  5   Gender           9233 non-null   object
#  6   Age              9233 non-null   int64
#  7   Tenure           9233 non-null   int64
#  8   Balance          9233 non-null   float64
#  9   NumOfProducts    9233 non-null   int64
#  10  HasCrCard        9233 non-null   int64
#  11  IsActiveMember   9233 non-null   int64
#  12  EstimatedSalary  9233 non-null   float64
#  13  Exited           9233 non-null   int64
# dtypes: float64(2), int32(2), int64(9), object(1)
# memory usage: 1009.9+ KB

# %%
df.isnull().any()
# Out:
# RowNumber          False
# CustomerId         False
# Surname            False
# CreditScore        False
# Geography          False
# Gender             False
# Age                False
# Tenure             False
# Balance            False
# NumOfProducts      False
# HasCrCard          False
# IsActiveMember     False
# EstimatedSalary    False
# Exited             False
# dtype: bool

# %%
df.Age.value_counts()
# Out:
# 37    478
# 38    477
# 35    474
# 36    456
# 34    447
#      ...
# 92      2
# 82      1
# 88      1
# 85      1
# 83      1
# Name: Age, Length: 70, dtype: int64

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# min         0.000000       1.000000      0.00000        0.000000
# 25%         0.000000       1.000000      0.00000        0.000000
# 50%     97198.540000       1.000000      1.00000        1.000000
# 75%    127644.240000       2.000000      1.00000        1.000000
# max    250898.090000       4.000000      1.00000        1.000000
#
#        EstimatedSalary        Exited
# count     10000.000000  10000.000000
# mean     100090.239881      0.203700
# std       57510.492818      0.402769
# min          11.580000      0.000000
# 25%       51002.110000      0.000000
# 50%      100193.915000      0.000000
# 75%      149388.247500      0.000000
# max      199992.480000      1.000000

# %% [markdown]
# ## Handling missing values

# %%
# for numerical column use mean or median for null value replacement
# for categorical columns use mode for null value replacement

# %%
# incase the one of the column contains null values then you can go for this code for the replacement of the null value

# df['Age'].fillna(df['Age'].median(),inplace=True)
        
# df['Age'].fillna(df['Age'].mean(),inplace=True)

# %% [markdown]
# ## Finding and replacing the outliers

# %% [markdown]
# ## Outlier Detection

# %%
sns.boxplot(df.Age)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# ## Outlier removal-IQR method

# %%
Q1 = df.Age.quantile(0.25)
Q3 = df.Age.quantile(0.75)

# %%
IQR = Q3-Q1

# %%
upper_limit = Q3 + 1.5*IQR
lower_limit = Q3 - 1.5*IQR

# %%
upper_limit
# Out:
# 62.0

# %%
lower_limit
# Out:
# 26.0

# %%
df = df[df.Age<upper_limit]

# %%
sns.boxplot(df.Age)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df.shape
# Out:
# (9589, 14)

# %% [markdown]
# ## Replacing the outliers using median

# %%
sns.boxplot(df.Age)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df.median()
# Out:
# C:\Users\zagir\AppData\Local\Temp\ipykernel_10944\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# RowNumber              5006.00
# CustomerId         15691104.00
# CreditScore             652.00
# Age                      37.00
# Tenure                    5.00
# Balance               97266.10
# NumOfProducts             1.00
# HasCrCard                 1.00
# IsActiveMember            1.00
# EstimatedSalary      100335.55
# Exited                    0.00
# dtype: float64

# %%
Q1 = df.Age.quantile(0.25)
Q3 = df.Age.quantile(0.75)

# %%
IQR = Q3-Q1

# %%
upper_limit = Q3 + 1.5*IQR
lower_limit = Q1 - 1.5*IQR

# %%
df['Age'] = np.where(df['Age']>upper_limit,30,df['Age'])
# Out:
# C:\Users\zagir\AppData\Local\Temp\ipykernel_10944\288602469.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'] = np.where(df['Age']>upper_limit,30,df['Age'])

# %%
sns.boxplot(df.Age)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df.shape
# Out:
# (9589, 14)

# %% [markdown]
# ## Outlier removal-Percentile method

# %%
sns.boxplot(df.Age)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
p99 = df.Age.quantile(0.96)
p99
# Out:
# 54.0

# %%
df = df[df.Age<=p99]

# %%
sns.boxplot(df.Age)
# Out:
# C:\Users\zagir\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# ## Check for categorical columns and perform encoding

# %% [markdown]
# ## Categorical columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9233 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        9233 non-null   int64
#  1   CustomerId       9233 non-null   int64
#  2   Surname          9233 non-null   object
#  3   CreditScore      9233 non-null   int64
#  4   Geography        9233 non-null   object
#  5   Gender           9233 non-null   object
#  6   Age              9233 non-null   int64
#  7   Tenure           9233 non-null   int64
#  8   Balance          9233 non-null   float64
#  9   NumOfProducts    9233 non-null   int64
#  10  HasCrCard        9233 non-null   int64
#  11  IsActiveMember   9233 non-null   int64
#  12  EstimatedSalary  9233 non-null   float64
#  13  Exited           9233 non-null   int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df.Surname = le.fit_transform(df.Surname)
df.Geography = le.fit_transform(df.Geography)

# %%
df.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  Age  \
# 0          1    15634602     1075          619          0  Female   42
# 1          2    15647311     1134          608          2  Female   41
# 2          3    15619304     1958          502          0  Female   42
# 3          4    15701354      283          699          0  Female   39
# 4          5    15737888     1748          850          2  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %% [markdown]
# ## One hot encoding

# %%
df_main = pd.get_dummies(df,columns=['Gender'])
df_main.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Age  Tenure  \
# 0          1    15634602     1075          619          0   42       2
# 1          2    15647311     1134          608          2   41       1
# 2          3    15619304     1958          502          0   42       8
# 3          4    15701354      283          699          0   39       1
# 4          5    15737888     1748          850          2   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  Gender_Female  Gender_Male
# 0       1              1            0
# 1       0              1            0
# 2       1              1            0
# 3       0              1            0
# 4       0              1            0

# %%
df_main.describe()
# Out:
#           RowNumber    CustomerId      Surname  CreditScore    Geography  \
# count   9233.000000  9.233000e+03  9233.000000  9233.000000  9233.000000
# mean    5006.143507  1.569077e+07  1448.071374   650.298928     0.741687
# std     2889.305509  7.180656e+04   809.064110    96.620251     0.827320
# min        1.000000  1.556570e+07     0.000000   350.000000     0.000000
# 25%     2500.000000  1.562831e+07   749.000000   583.000000     0.000000
# 50%     5025.000000  1.569074e+07  1482.000000   652.000000     0.000000
# 75%     7505.000000  1.575291e+07  2149.000000   717.000000     1.000000
# max    10000.000000  1.581569e+07  2810.000000   850.000000     2.000000
#
#                Age       Tenure        Balance  NumOfProducts    HasCrCard  \
# count  9233.000000  9233.000000    9233.000000    9233.000000  9233.000000
# mean     36.540019     5.014188   76293.575975       1.531896     0.705838
# std       7.501859     2.888136   62439.304138       0.575991     0.455690
# min      18.000000     0.000000       0.000000       1.000000     0.000000
# 25%      31.000000     3.000000       0.000000       1.000000     0.000000
# 50%      36.000000     5.000000   96863.130000       1.000000     1.000000
# 75%      42.000000     7.000000  127655.220000       2.000000     1.000000
# max      54.000000    10.000000  250898.090000       4.000000     1.000000
#
#        IsActiveMember  EstimatedSalary       Exited  Gender_Female  \
# count     9233.000000      9233.000000  9233.000000    9233.000000
# mean         0.497238    100487.855096     0.189321       0.451424
# std          0.500019     57563.153214     0.391785       0.497662
# min          0.000000        11.580000     0.000000       0.000000
# 25%          0.000000     51454.060000     0.000000       0.000000
# 50%          0.000000    100637.070000     0.000000       0.000000
# 75%          1.000000    149682.780000     0.000000       1.000000
# max          1.000000    199992.480000     1.000000       1.000000
#
#        Gender_Male
# count  9233.000000
# mean      0.548576
# std       0.497662
# min       0.000000
# 25%       0.000000
# 50%       1.000000
# 75%       1.000000
# max       1.000000

# %%
df_main.corr()
# Out:
#                  RowNumber  CustomerId   Surname  CreditScore  Geography  \
# RowNumber         1.000000    0.004099 -0.001113     0.000877  -0.007720
# CustomerId        0.004099    1.000000  0.001371     0.004856   0.004461
# Surname          -0.001113    0.001371  1.000000     0.006628  -0.028733
# CreditScore       0.000877    0.004856  0.006628     1.000000   0.006027
# Geography        -0.007720    0.004461 -0.028733     0.006027   1.000000
# Age               0.003233    0.002587 -0.006741    -0.015740   0.029023
# Tenure           -0.005368   -0.016898 -0.016142     0.000405   0.007473
# Balance          -0.011643   -0.008288  0.003292     0.009043   0.066133
# NumOfProducts     0.002625    0.016397 -0.016547     0.015053   0.006495
# HasCrCard        -0.000474   -0.018128 -0.005857    -0.003870  -0.010222
# IsActiveMember    0.016474    0.002671  0.001300     0.022779   0.005214
# EstimatedSalary  -0.008026    0.018867  0.012607     0.000814  -0.003192
# Exited           -0.014003   -0.003723 -0.006484    -0.026928   0.035266
# Gender_Female    -0.017521    0.003701  0.001931     0.005693  -0.005881
# Gender_Male       0.017521   -0.003701 -0.001931    -0.005693   0.005881
#
#                       Age    Tenure   Balance  NumOfProducts  HasCrCard  \
# RowNumber        0.003233 -0.005368 -0.011643       0.002625  -0.000474
# CustomerId       0.002587 -0.016898 -0.008288       0.016397  -0.018128
# Surname         -0.006741 -0.016142  0.003292      -0.016547  -0.005857
# CreditScore     -0.015740  0.000405  0.009043       0.015053  -0.003870
# Geography        0.029023  0.007473  0.066133       0.006495  -0.010222
# Age              1.000000 -0.009873  0.039132      -0.033216  -0.020130
# Tenure          -0.009873  1.000000 -0.015013       0.012327   0.021361
# Balance          0.039132 -0.015013  1.000000      -0.308241  -0.011169
# NumOfProducts   -0.033216  0.012327 -0.308241       1.000000  -0.000152
# HasCrCard       -0.020130  0.021361 -0.011169      -0.000152   1.000000
# IsActiveMember  -0.031338 -0.027388 -0.005581       0.012059  -0.010221
# EstimatedSalary  0.011367  0.007134  0.010133       0.010460  -0.010321
# Exited           0.318681 -0.013670  0.115465      -0.056042  -0.002915
# Gender_Female    0.026321 -0.013349 -0.012136       0.017026  -0.004266
# Gender_Male     -0.026321  0.013349  0.012136      -0.017026   0.004266
#
#                  IsActiveMember  EstimatedSalary    Exited  Gender_Female  \
# RowNumber              0.016474        -0.008026 -0.014003      -0.017521
# CustomerId             0.002671         0.018867 -0.003723       0.003701
# Surname                0.001300         0.012607 -0.006484       0.001931
# CreditScore            0.022779         0.000814 -0.026928       0.005693
# Geography              0.005214        -0.003192  0.035266      -0.005881
# Age                   -0.031338         0.011367  0.318681       0.026321
# Tenure                -0.027388         0.007134 -0.013670      -0.013349
# Balance               -0.005581         0.010133  0.115465      -0.012136
# NumOfProducts          0.012059         0.010460 -0.056042       0.017026
# HasCrCard             -0.010221        -0.010321 -0.002915      -0.004266
# IsActiveMember         1.000000        -0.009825 -0.135010      -0.019801
# EstimatedSalary       -0.009825         1.000000  0.014913       0.006952
# Exited                -0.135010         0.014913  1.000000       0.101060
# Gender_Female         -0.019801         0.006952  0.101060       1.000000
# Gender_Male            0.019801        -0.006952 -0.101060      -1.000000
#
#                  Gender_Male
# RowNumber           0.017521
# CustomerId         -0.003701
# Surname            -0.001931
# CreditScore        -0.005693
# Geography           0.005881
# Age                -0.026321
# Tenure              0.013349
# Balance             0.012136
# NumOfProducts      -0.017026
# HasCrCard           0.004266
# IsActiveMember      0.019801
# EstimatedSalary    -0.006952
# Exited             -0.101060
# Gender_Female      -1.000000
# Gender_Male         1.000000

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df_main.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Independent and dependent variable splits

# %%
#Taking HasCrCard as the independent variable
df_main.corr().HasCrCard.sort_values(ascending=False)
# Out:
# HasCrCard          1.000000
# Tenure             0.021361
# Gender_Male        0.004266
# NumOfProducts     -0.000152
# RowNumber         -0.000474
# Exited            -0.002915
# CreditScore       -0.003870
# Gender_Female     -0.004266
# Surname           -0.005857
# IsActiveMember    -0.010221
# Geography         -0.010222
# EstimatedSalary   -0.010321
# Balance           -0.011169
# CustomerId        -0.018128
# Age               -0.020130
# Name: HasCrCard, dtype: float64

# %%
df_main.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Age  Tenure  \
# 0          1    15634602     1075          619          0   42       2
# 1          2    15647311     1134          608          2   41       1
# 2          3    15619304     1958          502          0   42       8
# 3          4    15701354      283          699          0   39       1
# 4          5    15737888     1748          850          2   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited  Gender_Female  Gender_Male
# 0       1              1            0
# 1       0              1            0
# 2       1              1            0
# 3       0              1            0
# 4       0              1            0

# %% [markdown]
# ## Independent variables

# %%
X = df_main.drop(columns=['HasCrCard'],axis=1)
X.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Age  Tenure  \
# 0          1    15634602     1075          619          0   42       2
# 1          2    15647311     1134          608          2   41       1
# 2          3    15619304     1958          502          0   42       8
# 3          4    15701354      283          699          0   39       1
# 4          5    15737888     1748          850          2   43       2
#
#      Balance  NumOfProducts  IsActiveMember  EstimatedSalary  Exited  \
# 0       0.00              1               1        101348.88       1
# 1   83807.86              1               1        112542.58       0
# 2  159660.80              3               0        113931.57       1
# 3       0.00              2               0         93826.63       0
# 4  125510.82              1               1         79084.10       0
#
#    Gender_Female  Gender_Male
# 0              1            0
# 1              1            0
# 2              1            0
# 3              1            0
# 4              1            0

# %% [markdown]
# ## Dependent variables

# %%
y = df_main.HasCrCard
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 9995    1
# 9996    1
# 9997    0
# 9998    1
# 9999    1
# Name: HasCrCard, Length: 9233, dtype: int64

# %%
X.head()
# Out:
#    RowNumber  CustomerId  Surname  CreditScore  Geography  Age  Tenure  \
# 0          1    15634602     1075          619          0   42       2
# 1          2    15647311     1134          608          2   41       1
# 2          3    15619304     1958          502          0   42       8
# 3          4    15701354      283          699          0   39       1
# 4          5    15737888     1748          850          2   43       2
#
#      Balance  NumOfProducts  IsActiveMember  EstimatedSalary  Exited  \
# 0       0.00              1               1        101348.88       1
# 1   83807.86              1               1        112542.58       0
# 2  159660.80              3               0        113931.57       1
# 3       0.00              2               0         93826.63       0
# 4  125510.82              1               1         79084.10       0
#
#    Gender_Female  Gender_Male
# 0              1            0
# 1              1            0
# 2              1            0
# 3              1            0
# 4              1            0

# %% [markdown]
# ## Scaling the independent variables

# %%
from sklearn.preprocessing import scale

# %%
X_scaled = pd.DataFrame(scale(X),columns=X.columns)
X_scaled.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore  Geography       Age  \
# 0  -1.732394   -0.782275 -0.461140    -0.323955  -0.896542  0.727856
# 1  -1.732048   -0.605276 -0.388212    -0.437809   1.521032  0.594549
# 2  -1.731701   -0.995331  0.630304    -1.534947  -0.896542  0.727856
# 3  -1.731355    0.147384 -1.440102     0.504074  -0.896542  0.327934
# 4  -1.731009    0.656196  0.370731     2.066978   1.521032  0.861164
#
#      Tenure   Balance  NumOfProducts  IsActiveMember  EstimatedSalary  \
# 0 -1.043701 -1.221950      -0.923496        1.005539         0.014959
# 1 -1.389964  0.120352      -0.923496        1.005539         0.209429
# 2  1.033876  1.335245       2.548970       -0.994492         0.233560
# 3 -1.389964 -1.221950       0.812737       -0.994492        -0.115727
# 4 -1.043701  0.788284      -0.923496        1.005539        -0.371851
#
#      Exited  Gender_Female  Gender_Male
# 0  2.069308       1.102366    -1.102366
# 1 -0.483253       1.102366    -1.102366
# 2  2.069308       1.102366    -1.102366
# 3 -0.483253       1.102366    -1.102366
# 4 -0.483253       1.102366    -1.102366

# %% [markdown]
# ## Splitting the data into training and testing

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test =train_test_split(X_scaled,y, test_size=0.3,random_state=0)

# %%
X_train
# Out:
#       RowNumber  CustomerId   Surname  CreditScore  Geography       Age  \
# 5879   0.474831   -1.418713 -1.613150     0.431621  -0.896542 -0.471911
# 1906  -1.021458    0.558428  0.212515     1.000891  -0.896542  0.594549
# 6877   0.846913   -0.754978  0.443658    -0.800072   1.521032  0.994471
# 1457  -1.187597    0.031288 -0.808473     0.286716   0.312245 -1.804986
# 8094   1.304833    1.698385 -0.358546     1.621912   0.312245  0.061319
# ...         ...         ...       ...          ...        ...       ...
# 7891   1.227647    0.815758  1.117313    -1.886859  -0.896542 -1.938294
# 9225   1.726064   -0.468874 -1.143446     0.783533   1.521032 -0.071989
# 4859   0.098249    0.702252  0.601874    -0.386057   1.521032 -2.338216
# 3264  -0.507119   -0.613423 -1.030965     0.224614  -0.896542  0.861164
# 2732  -0.709601    1.625421  0.752674    -0.758670  -0.896542  1.261086
#
#         Tenure   Balance  NumOfProducts  IsActiveMember  EstimatedSalary  \
# 5879  1.380139 -1.221950      -0.923496       -0.994492         0.226165
# 1906 -0.004913 -1.221950       0.812737        1.005539        -1.350550
# 6877  1.033876 -1.221950       0.812737       -0.994492        -0.661282
# 1457  1.726401  0.628967      -0.923496        1.005539        -0.153828
# 8094  1.726401  0.861954       0.812737        1.005539         1.244094
# ...        ...       ...            ...             ...              ...
# 7891 -1.389964  0.000401      -0.923496        1.005539         1.638207
# 9225 -1.043701 -1.221950      -0.923496       -0.994492         1.645318
# 4859 -0.004913 -1.221950      -0.923496        1.005539         1.327579
# 3264 -0.004913 -1.221950      -0.923496       -0.994492        -0.636809
# 2732 -1.389964 -1.221950      -0.923496        1.005539         1.012207
#
#         Exited  Gender_Female  Gender_Male
# 5879  2.069308      -0.907140     0.907140
# 1906 -0.483253      -0.907140     0.907140
# 6877 -0.483253      -0.907140     0.907140
# 1457 -0.483253      -0.907140     0.907140
# 8094 -0.483253      -0.907140     0.907140
# ...        ...            ...          ...
# 7891 -0.483253       1.102366    -1.102366
# 9225 -0.483253      -0.907140     0.907140
# 4859 -0.483253      -0.907140     0.907140
# 3264 -0.483253      -0.907140     0.907140
# 2732 -0.483253       1.102366    -1.102366
#
# [6463 rows x 14 columns]

# %%
X_train.shape
# Out:
# (6463, 14)

# %%
y_train.shape
# Out:
# (6463,)

# %%
X_test
# Out:
#       RowNumber  CustomerId   Surname  CreditScore  Geography       Age  \
# 519   -1.539257    0.365928  1.514089     0.938789   1.521032  2.194239
# 4084  -0.191456    0.195210 -0.058183     1.673664   1.521032  1.661009
# 8276   1.371634   -1.648175  0.912126     0.690380   0.312245 -0.471911
# 1594  -1.138101   -0.090559 -0.535303     0.586876   1.521032 -0.205296
# 8509   1.456781    1.700795 -1.044561    -0.220452  -0.896542  0.327934
# ...         ...         ...       ...          ...        ...       ...
# 3348  -0.474238   -1.658468 -0.144708     0.928438  -0.896542  0.061319
# 4068  -0.198032    0.464155  1.376886     0.245315  -0.896542 -1.405064
# 818   -1.424691   -1.257744 -1.572360    -1.120933  -0.896542  0.861164
# 4265  -0.123962   -1.518584 -1.568652     1.352803  -0.896542 -1.138449
# 9119   1.686260   -1.651602  0.638956    -1.503896   0.312245 -0.471911
#
#         Tenure   Balance  NumOfProducts  IsActiveMember  EstimatedSalary  \
# 519  -0.697439 -1.221950       0.812737        1.005539        -1.069738
# 4084  1.033876 -0.163594       0.812737       -0.994492        -0.155165
# 8276 -1.736227  0.632387      -0.923496        1.005539        -0.329738
# 1594 -0.697439 -0.314228      -0.923496       -0.994492        -1.433294
# 8509  1.726401 -1.221950       0.812737        1.005539        -0.995715
# ...        ...       ...            ...             ...              ...
# 3348 -0.004913 -1.221950       0.812737        1.005539        -1.267537
# 4068  0.341350  1.440907      -0.923496        1.005539         0.849227
# 818   1.033876  1.110335      -0.923496        1.005539        -1.565967
# 4265 -0.351176 -1.221950       0.812737       -0.994492         1.341474
# 9119 -0.697439  0.483907       2.548970       -0.994492        -0.956255
#
#         Exited  Gender_Female  Gender_Male
# 519  -0.483253      -0.907140     0.907140
# 4084  2.069308       1.102366    -1.102366
# 8276 -0.483253       1.102366    -1.102366
# 1594  2.069308       1.102366    -1.102366
# 8509  2.069308       1.102366    -1.102366
# ...        ...            ...          ...
# 3348 -0.483253       1.102366    -1.102366
# 4068 -0.483253      -0.907140     0.907140
# 818  -0.483253       1.102366    -1.102366
# 4265 -0.483253       1.102366    -1.102366
# 9119  2.069308       1.102366    -1.102366
#
# [2770 rows x 14 columns]
